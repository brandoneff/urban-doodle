# %%
import numpy as np
import os
from matplotlib import pyplot as plt 
plt.style.use('ggplot')

# %%
k = 4.20 # constant
x_0 = 0 # equilibrium (initial position)
x = 1 # displacement of the spring
v = 0 # velocity
F = -k * (x-x_0) # Hooke's Law
m = 1 # mass 
a = F / m # acceleration
w = 1 # Frequency

N = 1000 # number of steps
dt = .01 # time step

# %%
# From Python for Verlet: TEST 3

v_0 = 0.0   #initial velocity
dv = (k * x) / m
ta, xa = [], []

position_e = np.zeros(N)
velocity_e = np.zeros(N)

for i in range(N):
    
    position_e[i] = x + dt * v
    velocity_e[i] = v + dv * dt
    
    x = (x + v * dt)
    v = (v - (k / m) * x * dt)

# %%
plt.plot(position_e)
